# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}&fq={filter_query}&sort={sort}&fl={field_list}"
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=2K5Y34WpqCil54dkvevh3WYPuRZGZwA4&begin_date=20130101&end_date=20230531&fq=section_name:"Movies" AND type_of_material:"Review" AND headline:"love"&sort=newest&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count'

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(20):
    # create query with a page number
    # API results show 10 articles at a time
    query = f'{query_url}&page={page}'
    
    # Make a "GET" request and retrieve the JSON
    response = requests.get(query).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        for doc in response["response"]["docs"]:
            reviews_list.append(doc)
        # Print the page that was just retrieved
        print(f"Retrieved page {page}")

        # Print the page number that had no results then break from the loop
    except Exception as e:
        print(f"No results on page {page}")
        print(f'Exception {e}')
# Out:
# Retrieved page 0
# Retrieved page 1
# Retrieved page 2
# Retrieved page 3
# Retrieved page 4
# Retrieved page 5
# Retrieved page 6
# Retrieved page 7
# Retrieved page 8
# Retrieved page 9
# Retrieved page 10
# Retrieved page 11
# Retrieved page 12
# Retrieved page 13
# Retrieved page 14
# Retrieved page 15
# Retrieved page 16
# Retrieved page 17
# Retrieved page 18
# Retrieved page 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list[:5], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = pd.json_normalize(reviews_list)
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'creative_works', 'value': 'Love & T...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'creative_works', 'value': 'Kedi (Mo...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
# [200 rows x 16 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_df['title'] = reviews_df['headline.main'].str.extract(r'\u2018(.*?)\u2019') 
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'creative_works', 'value': 'Love & T...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'creative_works', 'value': 'Kedi (Mo...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
#                          title
# 0       The Attachment Diaries
# 1                         What
# 2         You Can Live Forever
# 3                    A Tourist
# 4                 Other People
# ..                         ...
# 195             The Other Half
# 196     The Ottoman Lieutenant
# 197               Love & Taxes
# 198  Everybody Loves Somebody,
# 199                      Kedi,
#
# [200 rows x 17 columns]

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_df['keywords'] = reviews_df['keywords'].apply(lambda x: extract_keywords(x) if isinstance(x, list) else x)
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;persons: Kapur, Shekhar;person...
# 2    subject: Movies;creative_works: You Can Live F...
# 3    subject: Movies;creative_works: A Tourist's Gu...
# 4    subject: Movies;persons: Zlotowski, Rebecca;cr...
# ..                                                 ...
# 195  subject: Movies;creative_works: The Other Half...
# 196  subject: Movies;creative_works: The Ottoman Li...
# 197  creative_works: Love & Taxes (Movie);persons: ...
# 198  subject: Movies;creative_works: Everybody Love...
# 199  creative_works: Kedi (Movie);subject: Document...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
#                          title
# 0       The Attachment Diaries
# 1                         What
# 2         You Can Live Forever
# 3                    A Tourist
# 4                 Other People
# ..                         ...
# 195             The Other Half
# 196     The Ottoman Lieutenant
# 197               Love & Taxes
# 198  Everybody Loves Somebody,
# 199                      Kedi,
#
# [200 rows x 17 columns]

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles_list = reviews_df['title'].to_list()
titles_list
# Out:
# ['The Attachment Diaries',
#  'What',
#  'You Can Live Forever',
#  'A Tourist',
#  'Other People',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'About Fate',
#  'Waiting for Bojangles',
#  'I Love My Dad',
#  'A Love Song',
#  'Alone Together',
#  'Art of Love',
#  'The Wheel',
#  'Thor: Love and Thunder',
#  'Both Sides of the Blade',
#  'Fire of Love',
#  'Love & Gelato',
#  'Stay Prayed Up',
#  'Benediction',
#  'Dinner in America',
#  'In a New York Minute',
#  'Anaïs in Love',
#  'I Love America',
#  'See You Then',
#  'La Mami',
#  'Love After Love',
#  'Deep Water',
#  'Lucy and Desi',
#  'Cyrano',
#  'The In Between',
#  'Book of Love',
#  'Lingui, the Sacred Bonds',
#  'The Pink Cloud',
#  'A Journal for Jordan',
#  'West Side Story',
#  'Aulcie',
#  'Love Is Love Is Love',
#  'Love Hard',
#  'Bergman Island',
#  'Hard Luck Love Song',
#  'South of Heaven',
#  'Wife of a Spy',
#  'Happier Than Ever',
#  'Together',
#  'Annette',
#  'Resort to Love',
#  'Woodstock 99: Peace, Love and Rage',
#  'Casanova, Last Love',
#  'Running Against the Wind',
#  'Asia',
#  'Undine',
#  'This Town',
#  'Tu Me Manques',
#  'Monday',
#  'Ride or Die',
#  'Future People',
#  'Luz',
#  'Happily',
#  'This Is the Life',
#  'To All the Boys: Always and Forever',
#  'Young Hearts',
#  'Little Fish',
#  'Two of Us',
#  'Atlantis',
#  'Preparations to Be Together',
#  'Your Name Engraved Herein',
#  'Sylvie',
#  'Ariana Grande: Excuse Me, I Love You',
#  'Museum Town',
#  'Wild Mountain Thyme',
#  'My Psychedelic Love Story',
#  '69: The Saga of Danny Hernandez',
#  'Ammonite',
#  'Love and Monsters',
#  'Dick Johnson Is Dead',
#  'Love, Guaranteed',
#  'Feel the Beat',
#  'Babyteeth',
#  'Spelling the Dream',
#  'A Secret Love',
#  'Love Wedding Repeat',
#  'Almost Love',
#  'Hope Gap',
#  'All the Bright Places',
#  'The Photograph',
#  'You Go to My Head',
#  'Ordinary Love',
#  'To All the Boys: P.S. I Still Love You',
#  'The Woman Who Loves Giraffes',
#  'Queen & Slim',
#  'Marriage Story',
#  'Cyrano, My Love',
#  'Pretenders',
#  'First Love',
#  'Loro',
#  'Falling Inn Love',
#  'Hot Air',
#  'Love, Antosha',
#  'Leto',
#  'The Tomorrow Man',
#  'Asako I & II',
#  'The Sun Is Also a Star',
#  'Shéhérazade',
#  'Long Shot',
#  'Clara',
#  'Kalank',
#  'Rafiki',
#  'Diane',
#  'Five Feet Apart',
#  'Ash Is Purest White',
#  'Gloria Bell',
#  'Black Mother',
#  'The Hole in the Ground',
#  'How to Train Your Dragon: The Hidden World',
#  'A Tuba to Cuba',
#  'Fighting With My Family',
#  'Sorry Angel',
#  'Berlin, I Love You',
#  'Untogether',
#  'Cold War',
#  'If Beale Street Could Talk',
#  'Asher',
#  'The Party',
#  'The Great Pretender',
#  'Sicilian Ghost Story',
#  'The New Romantic',
#  'Pimp',
#  'In a Relationship',
#  'They',
#  'Burning,',
#  'After Everything,',
#  'Quincy',
#  'Love, Gilda,',
#  'Tea With the Dames,',
#  'Bel Canto,',
#  'The Citizen,',
#  'Love, Cecil,',
#  'How to Talk to Girls at Parties',
#  'Rogers Park,',
#  'Love & Bananas,',
#  'Godard Mon Amour',
#  'Submergence,',
#  'Love After Love,',
#  'Outside In',
#  'Love, Simon,',
#  'Keep the Change,',
#  'The Party',
#  'The Housemaid,',
#  'Forever My Girl,',
#  'Kangaroo: A Love-Hate Story',
#  'Lover for a Day',
#  'Youth,',
#  'Killing for Love',
#  'The Shape of Water',
#  'Love Beats Rhymes,',
#  'Cuba and the Cameraman',
#  'On the Beach at Night Alone',
#  'Thelma,',
#  'Hello Again,',
#  'It Happened in L.A.,',
#  'God',
#  'The Mountain Between Us',
#  'Dina,',
#  'In Search of Fellini',
#  'Woodpeckers,',
#  'I Do ... Until I Don',
#  'Tales of an Immoral Couple',
#  'After Love',
#  'The Last Face',
#  'Women Who Kill,',
#  'False Confessions,',
#  nan,
#  'The Big Sick,',
#  'Lost in Paris',
#  'Vincent N Roxxy,',
#  'Everything, Everything',
#  'Hounds of Love',
#  'Harold and Lillian',
#  'The Happiest Day in the Life of Olli Maki,',
#  'The Promise',
#  'Frantz,',
#  'The Other Half',
#  'The Ottoman Lieutenant',
#  'Love & Taxes',
#  'Everybody Loves Somebody,',
#  'Kedi,']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
results_list = []

# Create a request counter to sleep the requests after a multiple of 50 requests
request_counter = 0

# Loop through the titles
for title in titles_list:
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0 and request_counter != 0:
        time.sleep(10)
    
    # Add 1 to the request counter
    request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    response = requests.get(f'{url}{title}&{tmdb_key_string}')
    
    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie is not found.
    try:
        # Get movie id
        movie_id = response.json()['results'][0]['id']
        movie_id = str(movie_id)
        # Make a request for the full movie details
        movie_details_response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}?{tmdb_key_string}')
        
        # Execute "GET" request with url
        movie_details = movie_details_response.json()
        
        # Extract the genre names into a list
        genres = [genre['name'] for genre in movie_details['genres']]
        
        # Extract the spoken_languages' English name into a list
        spoken_languages = [language['english_name'] for language in movie_details['spoken_languages']]
        
        # Extract the production_countries' name into a list
        production_countries = [country['name'] for country in movie_details['production_countries']]
        
        # Add the relevant data to a dictionary and append it to the results_list
        movie_data = {           
        }
        movie_data['title'] = title
        for key, value in movie_details.items():
            if key == 'genres':
                
                movie_data['genres'] = genres
            elif key == 'spoken_languages':
                
                movie_data['spoken_languages'] = spoken_languages
            elif key == 'production_countries':
                
                movie_data['production_countries'] = production_countries
            else:
                movie_data[key] = value
                
        results_list.append(movie_data)
            
        # Print out the title that was found
        print(f"Found movie: {title}")
    
    except Exception as e:
        print(f"Movie not found: {title}")
        print(f"exception {e}")
# Out:
# Found movie: The Attachment Diaries
# Found movie: What
# Found movie: You Can Live Forever
# Found movie: A Tourist
# Found movie: Other People
# Found movie: One True Loves
# Found movie: The Lost Weekend: A Love Story
# Found movie: A Thousand and One
# Found movie: Your Place or Mine
# Found movie: Love in the Time of Fentanyl
# Found movie: Pamela, a Love Story
# Found movie: In From the Side
# Found movie: After Love
# Found movie: Alcarràs
# Found movie: Nelly & Nadine
# Found movie: Lady Chatterley
# Found movie: The Sound of Christmas
# Found movie: The Inspection
# Found movie: Bones and All
# Found movie: My Policeman
# Found movie: About Fate
# Found movie: Waiting for Bojangles
# Found movie: I Love My Dad
# Found movie: A Love Song
# Found movie: Alone Together
# Found movie: Art of Love
# Found movie: The Wheel
# Found movie: Thor: Love and Thunder
# Found movie: Both Sides of the Blade
# Found movie: Fire of Love
# Found movie: Love & Gelato
# Found movie: Stay Prayed Up
# Found movie: Benediction
# Found movie: Dinner in America
# Found movie: In a New York Minute
# Found movie: Anaïs in Love
# Found movie: I Love America
# Found movie: See You Then
# Found movie: La Mami
# Found movie: Love After Love
# Found movie: Deep Water
# Found movie: Lucy and Desi
# Found movie: Cyrano
# Found movie: The In Between
# Found movie: Book of Love
# Found movie: Lingui, the Sacred Bonds
# Found movie: The Pink Cloud
# Found movie: A Journal for Jordan
# Found movie: West Side Story
# Movie not found: Aulcie
# exception list index out of range
# Found movie: Love Is Love Is Love
# Found movie: Love Hard
# Found movie: Bergman Island
# Found movie: Hard Luck Love Song
# Found movie: South of Heaven
# Found movie: Wife of a Spy
# Found movie: Happier Than Ever
# Found movie: Together
# Found movie: Annette
# Found movie: Resort to Love
# Found movie: Woodstock 99: Peace, Love and Rage
# Found movie: Casanova, Last Love
# Found movie: Running Against the Wind
# Found movie: Asia
# Found movie: Undine
# Found movie: This Town
# Found movie: Tu Me Manques
# Found movie: Monday
# Found movie: Ride or Die
# Found movie: Future People
# Found movie: Luz
# Found movie: Happily
# Found movie: This Is the Life
# Found movie: To All the Boys: Always and Forever
# Found movie: Young Hearts
# Found movie: Little Fish
# Found movie: Two of Us
# Found movie: Atlantis
# Found movie: Preparations to Be Together
# Found movie: Your Name Engraved Herein
# Found movie: Sylvie
# Found movie: Ariana Grande: Excuse Me, I Love You
# Found movie: Museum Town
# Found movie: Wild Mountain Thyme
# Found movie: My Psychedelic Love Story
# Found movie: 69: The Saga of Danny Hernandez
# Found movie: Ammonite
# Found movie: Love and Monsters
# Found movie: Dick Johnson Is Dead
# Found movie: Love, Guaranteed
# Found movie: Feel the Beat
# Found movie: Babyteeth
# Found movie: Spelling the Dream
# Found movie: A Secret Love
# Found movie: Love Wedding Repeat
# Found movie: Almost Love
# Found movie: Hope Gap
# Found movie: All the Bright Places
# Found movie: The Photograph
# Found movie: You Go to My Head
# Found movie: Ordinary Love
# Found movie: To All the Boys: P.S. I Still Love You
# Found movie: The Woman Who Loves Giraffes
# Found movie: Queen & Slim
# Found movie: Marriage Story
# Found movie: Cyrano, My Love
# Found movie: Pretenders
# Found movie: First Love
# Found movie: Loro
# Found movie: Falling Inn Love
# Found movie: Hot Air
# Found movie: Love, Antosha
# Found movie: Leto
# Found movie: The Tomorrow Man
# Found movie: Asako I & II
# Found movie: The Sun Is Also a Star
# Found movie: Shéhérazade
# Found movie: Long Shot
# Found movie: Clara
# Found movie: Kalank
# Found movie: Rafiki
# Found movie: Diane
# Found movie: Five Feet Apart
# Found movie: Ash Is Purest White
# Found movie: Gloria Bell
# Found movie: Black Mother
# Found movie: The Hole in the Ground
# Found movie: How to Train Your Dragon: The Hidden World
# Found movie: A Tuba to Cuba
# Found movie: Fighting With My Family
# Found movie: Sorry Angel
# Found movie: Berlin, I Love You
# Found movie: Untogether
# Found movie: Cold War
# Found movie: If Beale Street Could Talk
# Found movie: Asher
# Found movie: The Party
# Found movie: The Great Pretender
# Found movie: Sicilian Ghost Story
# Found movie: The New Romantic
# Found movie: Pimp
# Found movie: In a Relationship
# Found movie: They
# Found movie: Burning,
# Found movie: After Everything,
# Found movie: Quincy
# Found movie: Love, Gilda,
# Found movie: Tea With the Dames,
# Found movie: Bel Canto,
# Found movie: The Citizen,
# Found movie: Love, Cecil,
# Found movie: How to Talk to Girls at Parties
# Found movie: Rogers Park,
# Found movie: Love & Bananas,
# Found movie: Godard Mon Amour
# Found movie: Submergence,
# Found movie: Love After Love,
# Found movie: Outside In
# Found movie: Love, Simon,
# Found movie: Keep the Change,
# Found movie: The Party
# Found movie: The Housemaid,
# Found movie: Forever My Girl,
# Found movie: Kangaroo: A Love-Hate Story
# Found movie: Lover for a Day
# Found movie: Youth,
# Found movie: Killing for Love
# Found movie: The Shape of Water
# Found movie: Love Beats Rhymes,
# Found movie: Cuba and the Cameraman
# Found movie: On the Beach at Night Alone
# Found movie: Thelma,
# Found movie: Hello Again,
# Found movie: It Happened in L.A.,
# Found movie: God
# Found movie: The Mountain Between Us
# Found movie: Dina,
# Found movie: In Search of Fellini
# Found movie: Woodpeckers,
# Found movie: I Do ... Until I Don
# Found movie: Tales of an Immoral Couple
# Found movie: After Love
# Found movie: The Last Face
# Found movie: Women Who Kill,
# Found movie: False Confessions,
# Found movie: nan
# Found movie: The Big Sick,
# Found movie: Lost in Paris
# Found movie: Vincent N Roxxy,
# Found movie: Everything, Everything
# Found movie: Hounds of Love
# Found movie: Harold and Lillian
# Found movie: The Happiest Day in the Life of Olli Maki,
# Found movie: The Promise
# Found movie: Frantz,
# Found movie: The Other Half
# Found movie: The Ottoman Lieutenant
# Found movie: Love & Taxes
# Found movie: Everybody Loves Somebody,
# Found movie: Kedi,

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(results_list[:5], indent=4))
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "adult": false,
#         "backdrop_path": null,
#         "belongs_to_collection": null,
#         "budget": 0,
#         "genres": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "homepage": "",
#         "id": 743040,
#         "imdb_id": "tt11359158",
#         "original_language": "es",
#         "original_title": "El apego",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 2.325,
#         "poster_path": "/hKZHk6I1p58ZeXbwjQok7DSWfZ.jpg",
#         "production_companies": [],
#         "production_countries": [
#             "Argentina"
#         ],
#         "release_date": "2021-10-07",
#         "revenue": 0,
#         "runtime": 102,
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "status": "Released",
#         "tagline": "",
#         "video": false,
#         "vote_average": 3.0,
#         "vote_count": 3
#     },
#     {
#         "title": "What...",
#         "adult": false,
#         "backdrop_path": null,
#         "belongs_to_collection": null,
#         "budget": 0,
#         "genres": [
#             "Comedy",
#             "Drama"
#         ],
#         "homepage": "",
#         "id": 1242065,
#         "imdb_id": null,
#         "original_language": "en",
#         "original_title": "What...",
#         "overview": "It's another ordinary day for Ricky, until he meets the one person he never thought he would meet.",
#         "popularity": 2.288,
#         "poster_path": "/cRKFfDDDrE0JPXzNlNPjCeyXbya.jpg",
#         "production_companies": [
#             {
#                 "id": 193493,
#                 "logo_path": null,
#                 "name": "Mills Studios",
#                 "origin_country": ""
#             }
#         ],
#         "production_countries": [
#             "Australia"
#         ],
#         "release_date": "2024-04-19",
#         "revenue": 0,
#         "runtime": 0,
#         "spoken_languages": [
#             "English"
#         ],
#         "status": "Planned",
#         "tagline": "What in... What the... What...?",
#         "video": false,
#         "vote_average": 0.0,
#         "vote_count": 0
#     },
#     {
#         "title": "You Can Live Forever",
#         "adult": false,
#         "backdrop_path": "/sClvKM8C6a1DSPzMwkKjk8pNFDx.jpg",
#         "belongs_to_collection": null,
#         "budget": 0,
#         "genres": [
#             "Drama",
#             "Romance"
#         ],
#         "homepage": "https://gooddeedentertainment.com/you-can-live-forever/",
#         "id": 887580,
#         "imdb_id": "tt15782570",
#         "original_language": "en",
#         "original_title": "You Can Live Forever",
#         "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#         "popularity": 59.685,
#         "poster_path": "/10MJURrsPfDQmS2AP3fueOHJ0ch.jpg",
#         "production_companies": [
#             {
#                 "id": 63971,
#                 "logo_path": "/9U4LhiybfyhDPpzim20IIvBnC5l.png",
#                 "name": "Prospector Films",
#                 "origin_country": "CA"
#             },
#             {
#                 "id": 49937,
#                 "logo_path": "/j14jwTsJj6ok9IkUFewX7acufKu.png",
#                 "name": "Good Deed Entertainment",
#                 "origin_country": "US"
#             }
#         ],
#         "production_countries": [
#             "Canada",
#             "United States of America"
#         ],
#         "release_date": "2023-03-24",
#         "revenue": 15055,
#         "runtime": 96,
#         "spoken_languages": [
#             "English",
#             "French"
#         ],
#         "status": "Released",
#         "tagline": "",
#         "video": false,
#         "vote_average": 6.6,
#         "vote_count": 31
#     },
#     {
#         "title": "A Tourist's Guide to Love",
#         "adult": false,
#         "backdrop_path": "/z3Qc5a0grcCREAQKqI195P05dVf.jpg",
#         "belongs_to_collection": null,
#         "budget": 0,
#         "genres": [
#             "Romance",
#             "Comedy"
#         ],
#         "homepage": "https://www.netflix.com/title/81424906",
#         "id": 813726,
#         "imdb_id": "tt20115096",
#         "original_language": "en",
#         "original_title": "A Tourist's Guide to Love",
#         "overview": "After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.",
#         "popularity": 17.433,
#         "poster_path": "/uWkpjbBe4gRZilXRXbYfsMUZMhz.jpg",
#         "production_companies": [
#             {
#                 "id": 48782,
#                 "logo_path": null,
#                 "name": "Head First Productions",
#                 "origin_country": "US"
#             },
#             {
#                 "id": 78703,
#                 "logo_path": null,
#                 "name": "Muse Entertainment",
#                 "origin_country": "US"
#             },
#             {
#                 "id": 22018,
#                 "logo_path": null,
#                 "name": "Ben's Sister Productions",
#                 "origin_country": ""
#             },
#             {
#                 "id": 192391,
#                 "logo_path": null,
#                 "name": "Radius Squared Media Group",
#                 "origin_country": ""
#             },
#             {
#                 "id": 192389,
#                 "logo_path": null,
#                 "name": "Cook and Muse Entertainment",
#                 "origin_country": ""
#             }
#         ],
#         "production_countries": [
#             "United States of America"
#         ],
#         "release_date": "2023-04-21",
#         "revenue": 0,
#         "runtime": 96,
#         "spoken_languages": [
#             "English",
#             "Vietnamese"
#         ],
#         "status": "Released",
#         "tagline": "",
#         "video": false,
#         "vote_average": 6.3,
#         "vote_count": 153
#     },
#     {
#         "title": "Other People",
#         "adult": false,
#         "backdrop_path": "/fDi3FeuOZlI8yzCu3RKvIsgRnct.jpg",
#         "belongs_to_collection": null,
#         "budget": 0,
#         "genres": [
#             "Comedy",
#             "Drama"
#         ],
#         "homepage": "",
#         "id": 371449,
#         "imdb_id": "tt4158876",
#         "original_language": "en",
#         "original_title": "Other People",
#         "overview": "David, a struggling comedy writer fresh off from breaking up with his boyfriend, moves from New York City to Sacramento to help his sick mother. Living with his conservative father and much-younger sisters for the first time in ten years, he feels like a stranger in his childhood home. As his mother\u2019s health declines, David frantically tries to extract meaning from this horrible experience and convince everyone (including himself) that he's \"doing okay.\u201d",
#         "popularity": 8.349,
#         "poster_path": "/aC7VqBeovG1yPUtlOhUfXofKBkZ.jpg",
#         "production_companies": [
#             {
#                 "id": 13466,
#                 "logo_path": "/d2ewBAUkCGeYMj6bv2Z9PkzL5OA.png",
#                 "name": "Park Pictures Features",
#                 "origin_country": "US"
#             },
#             {
#                 "id": 63631,
#                 "logo_path": null,
#                 "name": "Gettin' Rad Productions",
#                 "origin_country": ""
#             }
#         ],
#         "production_countries": [
#             "United States of America"
#         ],
#         "release_date": "2016-09-09",
#         "revenue": 93000,
#         "runtime": 97,
#         "spoken_languages": [
#             "English"
#         ],
#         "status": "Released",
#         "tagline": "",
#         "video": false,
#         "vote_average": 6.3,
#         "vote_count": 192
#     }
# ]

# %%
# Convert the results to a DataFrame
movies_df = pd.json_normalize(results_list)
movies_df.drop(columns=['adult', 'backdrop_path', 'belongs_to_collection', 'status', 'tagline', 'video', 'production_companies','belongs_to_collection.id', 'belongs_to_collection.name', 'belongs_to_collection.poster_path', 'belongs_to_collection.backdrop_path'], inplace=True)
movies_df
# Out:
#                          title    budget                              genres  \
# 0       The Attachment Diaries         0  [Drama, Mystery, Thriller, Horror]
# 1                      What...         0                     [Comedy, Drama]
# 2         You Can Live Forever         0                    [Drama, Romance]
# 3    A Tourist's Guide to Love         0                   [Romance, Comedy]
# 4                 Other People         0                     [Comedy, Drama]
# ..                         ...       ...                                 ...
# 194             The Other Half         0                    [Drama, Romance]
# 195     The Ottoman Lieutenant  40000000               [Romance, Drama, War]
# 196                Art of Love         0            [Romance, Action, Drama]
# 197   Everybody Loves Somebody   2000000                   [Romance, Comedy]
# 198                       Kedi         0                           [Romance]
#
#                                               homepage       id     imdb_id  \
# 0                                                        743040  tt11359158
# 1                                                       1242065        None
# 2    https://gooddeedentertainment.com/you-can-live...   887580  tt15782570
# 3               https://www.netflix.com/title/81424906   813726  tt20115096
# 4                                                        371449   tt4158876
# ..                                                 ...      ...         ...
# 194                      http://theotherhalfmovie.com/   381015   tt4625334
# 195  https://www.uphe.com/movies/the-ottoman-lieute...   433356   tt4943322
# 196             https://www.netflix.com/title/81689799  1248795  tt28355490
# 197                                                      431093   tt5537228
# 198                                                      224609   tt1966496
#
#     original_language             original_title  \
# 0                  es                   El apego
# 1                  en                    What...
# 2                  en       You Can Live Forever
# 3                  en  A Tourist's Guide to Love
# 4                  en               Other People
# ..                ...                        ...
# 194                en             The Other Half
# 195                en     The Ottoman Lieutenant
# 196                tr            Romantik Hırsız
# 197                en   Everybody Loves Somebody
# 198                ta                       கேடி
#
#                                               overview  popularity  \
# 0    Argentina, 1970s. A desperate young woman goes...       2.325
# 1    It's another ordinary day for Ricky, until he ...       2.288
# 2    When Jaime, a gay teenager, is sent to live in...      59.685
# 3    After an unexpected break up, a travel executi...      17.433
# 4    David, a struggling comedy writer fresh off fr...       8.349
# ..                                                 ...         ...
# 194  A grief-stricken man and a bipolar woman fall ...       4.182
# 195  Lillie, a determined American woman, ventures ...      15.933
# 196  After learning that the art thief she has been...     334.607
# 197  On the surface, Clara Barron seems to have it ...       8.257
# 198  A happy-go-lucky student at a university gets ...       3.299
#
#                           poster_path                production_countries  \
# 0     /hKZHk6I1p58ZeXbwjQok7DSWfZ.jpg                         [Argentina]
# 1    /cRKFfDDDrE0JPXzNlNPjCeyXbya.jpg                         [Australia]
# 2    /10MJURrsPfDQmS2AP3fueOHJ0ch.jpg  [Canada, United States of America]
# 3    /uWkpjbBe4gRZilXRXbYfsMUZMhz.jpg          [United States of America]
# 4    /aC7VqBeovG1yPUtlOhUfXofKBkZ.jpg          [United States of America]
# ..                                ...                                 ...
# 194  /jZ32u1vf7lb25rpuPl6LWoZAUvD.jpg                            [Canada]
# 195  /c5E8KTDuGNdF4Lmv3OhsQ0W1zPw.jpg  [Turkey, United States of America]
# 196  /niVtvS9Kf8G1VDPSqurqHkaSSwm.jpg                            [Turkey]
# 197  /bZKpuVXmYu6gaprjfkOdvlvY5Z9.jpg                            [Mexico]
# 198  /3IP6uwxDSG3GqDnT1ffRLFtsjDx.jpg                             [India]
#
#     release_date  revenue  runtime       spoken_languages  vote_average  \
# 0     2021-10-07        0      102              [Spanish]         3.000
# 1     2024-04-19        0        0              [English]         0.000
# 2     2023-03-24    15055       96      [English, French]         6.600
# 3     2023-04-21        0       96  [English, Vietnamese]         6.300
# 4     2016-09-09    93000       97              [English]         6.300
# ..           ...      ...      ...                    ...           ...
# 194   2016-12-02        0      103              [English]         6.300
# 195   2017-03-10   413844      111     [Turkish, English]         6.200
# 196   2024-03-14        0       99              [Turkish]         6.686
# 197   2017-02-10        0      102     [English, Spanish]         6.600
# 198   2006-09-24        0      189                [Tamil]         4.000
#
#      vote_count
# 0             3
# 1             0
# 2            31
# 3           153
# 4           192
# ..          ...
# 194          24
# 195         243
# 196          78
# 197         158
# 198           2
#
# [199 rows x 18 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(reviews_df, movies_df, on='title')
merged_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/you-...
# 2    https://www.nytimes.com/2023/04/20/movies/othe...
# 3    https://www.nytimes.com/2023/04/13/movies/one-...
# 4    https://www.nytimes.com/2023/04/13/movies/the-...
# ..                                                 ...
# 145  https://www.nytimes.com/2017/05/18/movies/ever...
# 146  https://www.nytimes.com/2017/05/11/movies/houn...
# 147  https://www.nytimes.com/2017/04/20/movies/the-...
# 148  https://www.nytimes.com/2017/03/09/movies/the-...
# 149  https://www.nytimes.com/2017/03/09/movies/revi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Religion comes between two girls falling in lo...  The New York Times
# 2    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# 3    A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 4    There’s not much Lennon music heard in this do...  The New York Times
# ..                                                 ...                 ...
# 145  Amandla Stenberg plays a teenager with an immu...  The New York Times
# 146  This feature debut of the Australian filmmaker...  The New York Times
# 147  Oscar Isaac, Christian Bale and Charlotte Le B...  The New York Times
# 148  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 149  A nurse travels to the Ottoman Empire on the e...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;creative_works: You Can Live F...
# 2    subject: Movies;persons: Zlotowski, Rebecca;cr...
# 3    subject: Movies;persons: Bracey, Luke (1989- )...
# 4    subject: Documentary Films and Programs;creati...
# ..                                                 ...
# 145  subject: Movies;creative_works: Everything, Ev...
# 146  subject: Movies;creative_works: Hounds of Love...
# 147  subject: Movies;creative_works: The Promise (M...
# 148  subject: Movies;creative_works: The Other Half...
# 149  subject: Movies;creative_works: The Ottoman Li...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T11:00:08+0000         294
# 2    2023-04-20T15:35:13+0000         801
# 3    2023-04-13T11:00:06+0000         320
# 4    2023-04-13T11:00:03+0000         327
# ..                        ...         ...
# 145  2017-05-18T21:02:53+0000         270
# 146  2017-05-11T20:16:51+0000         280
# 147  2017-04-20T16:49:46+0000         455
# 148  2017-03-09T21:54:58+0000         251
# 149  2017-03-09T21:53:12+0000         267
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# 3       ‘One True Loves’ Review: A Romance Lost at Sea            None
# 4    ‘The Lost Weekend: A Love Story’ Review: When ...            None
# ..                                                 ...             ...
# 145  Review: ‘Everything, Everything’ Pits Love Aga...            None
# 146  Review: ‘Hounds of Love’ Is Tense and Deadly D...            None
# 147  Review: ‘The Promise’ Finds a Love Triangle in...            None
# 148  Review: A Combustible Pair Find Love in ‘The O...            None
# 149  Review: Love as the World Wars, in ‘The Ottoma...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 145                    None
# 146                    None
# 147                    None
# 148                    None
# 149                    None
#
#                                headline.print_headline  ...  \
# 0                               The Attachment Diaries  ...
# 1                                 You Can Live Forever  ...
# 2               Intoxicating Love With a Sobering Turn  ...
# 3                                       One True Loves  ...
# 4                      The Lost Weekend:  A Love Story  ...
# ..                                                 ...  ...
# 145                             Everything, Everything  ...
# 146                                     Hounds of Love  ...
# 147              A Love Triangle, Near the Front Lines  ...
# 148  Review: A Combustible Pair Find Love in ‘The O...  ...
# 149  Review: Love as the World Wars, in ‘The Ottoma...  ...
#
#                                               overview popularity  \
# 0    Argentina, 1970s. A desperate young woman goes...      2.325
# 1    When Jaime, a gay teenager, is sent to live in...     59.685
# 2    David, a struggling comedy writer fresh off fr...      8.349
# 3    Emma and Jesse are living the perfect life tog...     17.872
# 4    May Pang lovingly recounts her life in rock & ...      2.162
# ..                                                 ...        ...
# 145  A teenager who's lived a sheltered life becaus...     17.548
# 146  When Vicki Maloney is randomly abducted from a...     11.704
# 147  Set during the last days of the Ottoman Empire...     15.971
# 148  A grief-stricken man and a bipolar woman fall ...      4.182
# 149  Lillie, a determined American woman, ventures ...     15.933
#
#                           poster_path  \
# 0     /hKZHk6I1p58ZeXbwjQok7DSWfZ.jpg
# 1    /10MJURrsPfDQmS2AP3fueOHJ0ch.jpg
# 2    /aC7VqBeovG1yPUtlOhUfXofKBkZ.jpg
# 3    /6MF3JvIZkluUijw9rvDKNqPT8kC.jpg
# 4    /qlbOj1G3YtIDUGSzu1Y590EfSMY.jpg
# ..                                ...
# 145  /c8W3Go48Mw0GoNXsGK4W9hNO4Vf.jpg
# 146  /b4niGo8hpxIpmAZsGkpZK4mXiDo.jpg
# 147  /iDWer2VFikupdqDc7d5sxCWZ3gW.jpg
# 148  /jZ32u1vf7lb25rpuPl6LWoZAUvD.jpg
# 149  /c5E8KTDuGNdF4Lmv3OhsQ0W1zPw.jpg
#
#                            production_countries release_date   revenue  \
# 0                                   [Argentina]   2021-10-07         0
# 1            [Canada, United States of America]   2023-03-24     15055
# 2                    [United States of America]   2016-09-09     93000
# 3    [Czech Republic, United States of America]   2023-04-07     37820
# 4                    [United States of America]   2023-04-13     77145
# ..                                          ...          ...       ...
# 145                  [United States of America]   2017-05-18  61621140
# 146                                 [Australia]   2016-10-07         0
# 147           [Spain, United States of America]   2016-12-02  12448676
# 148                                    [Canada]   2016-12-02         0
# 149          [Turkey, United States of America]   2017-03-10    413844
#
#     runtime                     spoken_languages vote_average vote_count
# 0       102                            [Spanish]        3.000          3
# 1        96                    [English, French]        6.600         31
# 2        97                            [English]        6.300        192
# 3       100                   [English, Spanish]        6.500         65
# 4        95                            [English]        6.000          2
# ..      ...                                  ...          ...        ...
# 145      96                            [English]        7.247       3626
# 146     108                            [English]        6.100        323
# 147     133  [Armenian, German, English, French]        6.917        446
# 148     103                            [English]        6.300         24
# 149     111                   [Turkish, English]        6.200        243
#
# [150 rows x 34 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ['genres', 'spoken_languages', 'production_countries']

# Create a list of characters to remove
chars_to_remove = ["[", "]", "'"]

# Loop through the list of columns to fix
for col in columns_to_fix:
    # Convert the column to type 'str'
    merged_df[col] = merged_df[col].astype(str)

    # Loop through characters to remove
    for char in chars_to_remove:
        merged_df[col] = merged_df[col].str.replace(char, '')

# Display the fixed DataFrame
merged_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/you-...
# 2    https://www.nytimes.com/2023/04/20/movies/othe...
# 3    https://www.nytimes.com/2023/04/13/movies/one-...
# 4    https://www.nytimes.com/2023/04/13/movies/the-...
# ..                                                 ...
# 145  https://www.nytimes.com/2017/05/18/movies/ever...
# 146  https://www.nytimes.com/2017/05/11/movies/houn...
# 147  https://www.nytimes.com/2017/04/20/movies/the-...
# 148  https://www.nytimes.com/2017/03/09/movies/the-...
# 149  https://www.nytimes.com/2017/03/09/movies/revi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Religion comes between two girls falling in lo...  The New York Times
# 2    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# 3    A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 4    There’s not much Lennon music heard in this do...  The New York Times
# ..                                                 ...                 ...
# 145  Amandla Stenberg plays a teenager with an immu...  The New York Times
# 146  This feature debut of the Australian filmmaker...  The New York Times
# 147  Oscar Isaac, Christian Bale and Charlotte Le B...  The New York Times
# 148  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 149  A nurse travels to the Ottoman Empire on the e...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;creative_works: You Can Live F...
# 2    subject: Movies;persons: Zlotowski, Rebecca;cr...
# 3    subject: Movies;persons: Bracey, Luke (1989- )...
# 4    subject: Documentary Films and Programs;creati...
# ..                                                 ...
# 145  subject: Movies;creative_works: Everything, Ev...
# 146  subject: Movies;creative_works: Hounds of Love...
# 147  subject: Movies;creative_works: The Promise (M...
# 148  subject: Movies;creative_works: The Other Half...
# 149  subject: Movies;creative_works: The Ottoman Li...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T11:00:08+0000         294
# 2    2023-04-20T15:35:13+0000         801
# 3    2023-04-13T11:00:06+0000         320
# 4    2023-04-13T11:00:03+0000         327
# ..                        ...         ...
# 145  2017-05-18T21:02:53+0000         270
# 146  2017-05-11T20:16:51+0000         280
# 147  2017-04-20T16:49:46+0000         455
# 148  2017-03-09T21:54:58+0000         251
# 149  2017-03-09T21:53:12+0000         267
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# 3       ‘One True Loves’ Review: A Romance Lost at Sea            None
# 4    ‘The Lost Weekend: A Love Story’ Review: When ...            None
# ..                                                 ...             ...
# 145  Review: ‘Everything, Everything’ Pits Love Aga...            None
# 146  Review: ‘Hounds of Love’ Is Tense and Deadly D...            None
# 147  Review: ‘The Promise’ Finds a Love Triangle in...            None
# 148  Review: A Combustible Pair Find Love in ‘The O...            None
# 149  Review: Love as the World Wars, in ‘The Ottoma...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 145                    None
# 146                    None
# 147                    None
# 148                    None
# 149                    None
#
#                                headline.print_headline  ...  \
# 0                               The Attachment Diaries  ...
# 1                                 You Can Live Forever  ...
# 2               Intoxicating Love With a Sobering Turn  ...
# 3                                       One True Loves  ...
# 4                      The Lost Weekend:  A Love Story  ...
# ..                                                 ...  ...
# 145                             Everything, Everything  ...
# 146                                     Hounds of Love  ...
# 147              A Love Triangle, Near the Front Lines  ...
# 148  Review: A Combustible Pair Find Love in ‘The O...  ...
# 149  Review: Love as the World Wars, in ‘The Ottoma...  ...
#
#                                               overview popularity  \
# 0    Argentina, 1970s. A desperate young woman goes...      2.325
# 1    When Jaime, a gay teenager, is sent to live in...     59.685
# 2    David, a struggling comedy writer fresh off fr...      8.349
# 3    Emma and Jesse are living the perfect life tog...     17.872
# 4    May Pang lovingly recounts her life in rock & ...      2.162
# ..                                                 ...        ...
# 145  A teenager who's lived a sheltered life becaus...     17.548
# 146  When Vicki Maloney is randomly abducted from a...     11.704
# 147  Set during the last days of the Ottoman Empire...     15.971
# 148  A grief-stricken man and a bipolar woman fall ...      4.182
# 149  Lillie, a determined American woman, ventures ...     15.933
#
#                           poster_path  \
# 0     /hKZHk6I1p58ZeXbwjQok7DSWfZ.jpg
# 1    /10MJURrsPfDQmS2AP3fueOHJ0ch.jpg
# 2    /aC7VqBeovG1yPUtlOhUfXofKBkZ.jpg
# 3    /6MF3JvIZkluUijw9rvDKNqPT8kC.jpg
# 4    /qlbOj1G3YtIDUGSzu1Y590EfSMY.jpg
# ..                                ...
# 145  /c8W3Go48Mw0GoNXsGK4W9hNO4Vf.jpg
# 146  /b4niGo8hpxIpmAZsGkpZK4mXiDo.jpg
# 147  /iDWer2VFikupdqDc7d5sxCWZ3gW.jpg
# 148  /jZ32u1vf7lb25rpuPl6LWoZAUvD.jpg
# 149  /c5E8KTDuGNdF4Lmv3OhsQ0W1zPw.jpg
#
#                          production_countries release_date   revenue runtime  \
# 0                                   Argentina   2021-10-07         0     102
# 1            Canada, United States of America   2023-03-24     15055      96
# 2                    United States of America   2016-09-09     93000      97
# 3    Czech Republic, United States of America   2023-04-07     37820     100
# 4                    United States of America   2023-04-13     77145      95
# ..                                        ...          ...       ...     ...
# 145                  United States of America   2017-05-18  61621140      96
# 146                                 Australia   2016-10-07         0     108
# 147           Spain, United States of America   2016-12-02  12448676     133
# 148                                    Canada   2016-12-02         0     103
# 149          Turkey, United States of America   2017-03-10    413844     111
#
#                       spoken_languages vote_average vote_count
# 0                              Spanish        3.000          3
# 1                      English, French        6.600         31
# 2                              English        6.300        192
# 3                     English, Spanish        6.500         65
# 4                              English        6.000          2
# ..                                 ...          ...        ...
# 145                            English        7.247       3626
# 146                            English        6.100        323
# 147  Armenian, German, English, French        6.917        446
# 148                            English        6.300         24
# 149                   Turkish, English        6.200        243
#
# [150 rows x 34 columns]

# %%
# Drop "byline.person" column
merged_df.drop(columns=['byline.person'], inplace=True)

# %%
# Delete duplicate rows and reset index
merged_df.drop_duplicates(inplace=True)
merged_df.reset_index(drop=True, inplace=True)
merged_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/you-...
# 2    https://www.nytimes.com/2023/04/20/movies/othe...
# 3    https://www.nytimes.com/2023/04/13/movies/one-...
# 4    https://www.nytimes.com/2023/04/13/movies/the-...
# ..                                                 ...
# 136  https://www.nytimes.com/2017/05/18/movies/ever...
# 137  https://www.nytimes.com/2017/05/11/movies/houn...
# 138  https://www.nytimes.com/2017/04/20/movies/the-...
# 139  https://www.nytimes.com/2017/03/09/movies/the-...
# 140  https://www.nytimes.com/2017/03/09/movies/revi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Religion comes between two girls falling in lo...  The New York Times
# 2    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# 3    A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 4    There’s not much Lennon music heard in this do...  The New York Times
# ..                                                 ...                 ...
# 136  Amandla Stenberg plays a teenager with an immu...  The New York Times
# 137  This feature debut of the Australian filmmaker...  The New York Times
# 138  Oscar Isaac, Christian Bale and Charlotte Le B...  The New York Times
# 139  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 140  A nurse travels to the Ottoman Empire on the e...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;creative_works: You Can Live F...
# 2    subject: Movies;persons: Zlotowski, Rebecca;cr...
# 3    subject: Movies;persons: Bracey, Luke (1989- )...
# 4    subject: Documentary Films and Programs;creati...
# ..                                                 ...
# 136  subject: Movies;creative_works: Everything, Ev...
# 137  subject: Movies;creative_works: Hounds of Love...
# 138  subject: Movies;creative_works: The Promise (M...
# 139  subject: Movies;creative_works: The Other Half...
# 140  subject: Movies;creative_works: The Ottoman Li...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T11:00:08+0000         294
# 2    2023-04-20T15:35:13+0000         801
# 3    2023-04-13T11:00:06+0000         320
# 4    2023-04-13T11:00:03+0000         327
# ..                        ...         ...
# 136  2017-05-18T21:02:53+0000         270
# 137  2017-05-11T20:16:51+0000         280
# 138  2017-04-20T16:49:46+0000         455
# 139  2017-03-09T21:54:58+0000         251
# 140  2017-03-09T21:53:12+0000         267
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# 3       ‘One True Loves’ Review: A Romance Lost at Sea            None
# 4    ‘The Lost Weekend: A Love Story’ Review: When ...            None
# ..                                                 ...             ...
# 136  Review: ‘Everything, Everything’ Pits Love Aga...            None
# 137  Review: ‘Hounds of Love’ Is Tense and Deadly D...            None
# 138  Review: ‘The Promise’ Finds a Love Triangle in...            None
# 139  Review: A Combustible Pair Find Love in ‘The O...            None
# 140  Review: Love as the World Wars, in ‘The Ottoma...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 136                    None
# 137                    None
# 138                    None
# 139                    None
# 140                    None
#
#                                headline.print_headline  ...  \
# 0                               The Attachment Diaries  ...
# 1                                 You Can Live Forever  ...
# 2               Intoxicating Love With a Sobering Turn  ...
# 3                                       One True Loves  ...
# 4                      The Lost Weekend:  A Love Story  ...
# ..                                                 ...  ...
# 136                             Everything, Everything  ...
# 137                                     Hounds of Love  ...
# 138              A Love Triangle, Near the Front Lines  ...
# 139  Review: A Combustible Pair Find Love in ‘The O...  ...
# 140  Review: Love as the World Wars, in ‘The Ottoma...  ...
#
#                                               overview popularity  \
# 0    Argentina, 1970s. A desperate young woman goes...      2.325
# 1    When Jaime, a gay teenager, is sent to live in...     59.685
# 2    David, a struggling comedy writer fresh off fr...      8.349
# 3    Emma and Jesse are living the perfect life tog...     17.872
# 4    May Pang lovingly recounts her life in rock & ...      2.162
# ..                                                 ...        ...
# 136  A teenager who's lived a sheltered life becaus...     17.548
# 137  When Vicki Maloney is randomly abducted from a...     11.704
# 138  Set during the last days of the Ottoman Empire...     15.971
# 139  A grief-stricken man and a bipolar woman fall ...      4.182
# 140  Lillie, a determined American woman, ventures ...     15.933
#
#                           poster_path  \
# 0     /hKZHk6I1p58ZeXbwjQok7DSWfZ.jpg
# 1    /10MJURrsPfDQmS2AP3fueOHJ0ch.jpg
# 2    /aC7VqBeovG1yPUtlOhUfXofKBkZ.jpg
# 3    /6MF3JvIZkluUijw9rvDKNqPT8kC.jpg
# 4    /qlbOj1G3YtIDUGSzu1Y590EfSMY.jpg
# ..                                ...
# 136  /c8W3Go48Mw0GoNXsGK4W9hNO4Vf.jpg
# 137  /b4niGo8hpxIpmAZsGkpZK4mXiDo.jpg
# 138  /iDWer2VFikupdqDc7d5sxCWZ3gW.jpg
# 139  /jZ32u1vf7lb25rpuPl6LWoZAUvD.jpg
# 140  /c5E8KTDuGNdF4Lmv3OhsQ0W1zPw.jpg
#
#                          production_countries release_date   revenue  runtime  \
# 0                                   Argentina   2021-10-07         0      102
# 1            Canada, United States of America   2023-03-24     15055       96
# 2                    United States of America   2016-09-09     93000       97
# 3    Czech Republic, United States of America   2023-04-07     37820      100
# 4                    United States of America   2023-04-13     77145       95
# ..                                        ...          ...       ...      ...
# 136                  United States of America   2017-05-18  61621140       96
# 137                                 Australia   2016-10-07         0      108
# 138           Spain, United States of America   2016-12-02  12448676      133
# 139                                    Canada   2016-12-02         0      103
# 140          Turkey, United States of America   2017-03-10    413844      111
#
#                       spoken_languages vote_average  vote_count
# 0                              Spanish        3.000           3
# 1                      English, French        6.600          31
# 2                              English        6.300         192
# 3                     English, Spanish        6.500          65
# 4                              English        6.000           2
# ..                                 ...          ...         ...
# 136                            English        7.247        3626
# 137                            English        6.100         323
# 138  Armenian, German, English, French        6.917         446
# 139                            English        6.300          24
# 140                   Turkish, English        6.200         243
#
# [141 rows x 33 columns]

# %%
# Export data to CSV without the index
merged_df.to_csv('../output/final_output.csv', index=False)
